# %%
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv(r'C:\Users\Asus\superstore_sales.csv')

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
# Convert order_date to datetime
df['order_date'] = pd.to_datetime(df['order_date'], format='%d-%m-%Y')

# Create Month-Year column
df['Month-Year'] = df['order_date'].dt.to_period('M').astype(str)

# Optional: Sort by Order Date
df = df.sort_values('order_date')

# %%
monthly_sales = df.groupby('Month-Year')['sales'].sum().reset_index()

# %%
region_sales = df.groupby('region')['sales'].sum().reset_index()

# %%
category_sales = df.groupby('category')['sales'].sum().reset_index()

# %%
df.to_csv('cleaned_superstore_sales.csv', index=False)
monthly_sales.to_csv('monthly_sales.csv', index=False)
region_sales.to_csv('region_sales.csv', index=False)
category_sales.to_csv('category_sales.csv', index=False)

# %%
# Step 1: Convert 'order_date' to datetime and create 'Month-Year' column
df['order_date'] = pd.to_datetime(df['order_date'], format='%d-%m-%Y')

# Create Month-Year column
df['Month-Year'] = df['order_date'].dt.to_period('M').astype(str)

# Sort the DataFrame by 'order_date'
df = df.sort_values('order_date')

# Display the updated DataFrame
df[['order_date', 'Month-Year']].head()
# Out:
#   order_date Month-Year
# 0 2011-01-01    2011-01
# 1 2011-01-01    2011-01
# 2 2011-01-01    2011-01
# 3 2011-01-01    2011-01
# 4 2011-01-01    2011-01

# %%
# Export cleaned full dataset
df.to_csv('cleaned_superstore_sales.csv', index=False)

# Export visual-specific summaries
monthly_sales.to_csv('monthly_sales.csv', index=False)
region_sales.to_csv('region_sales.csv', index=False)
category_sales.to_csv('category_sales.csv', index=False)
